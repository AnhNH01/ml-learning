# %%
# ref: https://github.com/shubhamjha97/association-rule-mining-apriori/blob/master/arm.py

# %%
import csv
from itertools import combinations

data_path = '/home/haianh/grad_project/ml-learning/data/groceries.csv'

# %%
def read(data_path: str):
    transactions = []
    items = []
    with open(data_path, 'r') as f:
        reader = csv.reader(f)
        for line in reader:
            transactions.append(line)
            items.extend(line)
        unique_items = sorted(set(items))
    return transactions, unique_items

# transactions, items = read(data_path)

# %%
transactions, items = read(data_path)

print(f'Transactions: {len(transactions)}, Unique items: {len(items)}')
# Out:
# Transactions: 9835, Unique items: 169

# %%
def generate_candidate(list_k_item_candidtates: list):
    """
    Generate k+1 itemset candidate from list of k-item set candidate
    
    Eg:
        [
            [1, 2, 3],
            [1, 2, 4],
            [1, 2, 5],
        ]
        -->
        [
            [1, 2, 3, 4], 
            [1, 2, 3, 5],
            [1, 2, 4, 5],        
        ]
    
    
    """
    n = len(list_k_item_candidtates)
    new_candidates = []

    for i in range(n):
        for j in range(i + 1, n):
            candidate_a = list_k_item_candidtates[i]
            candidate_b = list_k_item_candidtates[j]

            if candidate_a[:-1] == candidate_b[:-1]:
                temp_candidate = []
                temp_candidate.extend(candidate_a)
                temp_candidate.append(candidate_b[-1])
                temp_candidate = sorted(temp_candidate)
                new_candidates.append(temp_candidate)
    
    return new_candidates

# %%
def get_support(candidate_list, transactions):
    """
    Get support of candidate in transactions

    return:  dictionary with key = candidate, value = support 
        {
            (1, 2, 4, ) : 1,
            
            (1, 3, 5, ) : 2
        } 
    
    """
    candidate_support = {}

    for transaction in transactions:
        for candidate in candidate_list:
            # if all items in candidate exist in a transaction, increment support of it
            if set(candidate).issubset(set(transaction)):
                candidate_support[tuple(sorted(candidate))] = candidate_support.get(tuple(candidate), 0)
                candidate_support[tuple(sorted(candidate))] += 1

    return candidate_support

# %%
get_support([[1, 2], [2], [3]], [[1, 2, 4], [1, 2, 5], [2, 3, 5]])
# Out:
# {(1, 2): 2, (2,): 3, (3,): 1}

# %%
def generate_frequent_itemsets(data_path, min_sup = 0.1) -> list[dict]:
    transactions, items = read(data_path)
    
    one_itemset = [[item] for item in items]

    temp_candidate_support =  get_support(one_itemset, transactions)

    final_candidate_support = []

    min_support_count = min_sup * len(transactions)
    candidate_support = {}

    # prune candidates which does not meet minimum support 
    for candidate in temp_candidate_support.keys():
        if temp_candidate_support[candidate] >= min_support_count:
            candidate_support[tuple(sorted(candidate))] = temp_candidate_support[candidate]

    final_candidate_support.append(candidate_support)

    # Generate k+1 itemset from list of k-itemset
    while(len(candidate_support)):
        current_candidates = generate_candidate(list(candidate_support.keys()))
        
        if(len(current_candidates)):

            temp_dict_candidate_support = get_support(current_candidates, transactions)
            
            candidate_support = {}
            for candidate in temp_dict_candidate_support.keys():
                if temp_dict_candidate_support[candidate] >= min_support_count:
                    candidate_support[tuple(sorted(candidate))] = temp_dict_candidate_support[candidate]
            
            if len(candidate_support):
                final_candidate_support.append(candidate_support)

        else:
            break
    
    return final_candidate_support

# %%
frequent_itemsets = generate_frequent_itemsets(data_path, min_sup=0.01)

frequent_itemsets

# %%
def check_key(list_dict: list[dict[tuple, int]], key: tuple):
    for dict in list_dict:
        if key in dict.keys():
            return True
    return False

# %%
def generate_rules(frequent_itemsets: list[dict], min_confidence=0.5) -> list[dict]:
    """
    Generate association rule from frequent set

    Params:
    ------
    frequent_itemsets: list[dict]: contains dict <candidate, support_count>

    return: list of association rule

    rule format:
    [(antecedent, consequent), (antedecent, consequent)]
    """
    rules = []

    for k_itemset in frequent_itemsets:
        k = len(list(k_itemset.keys())[0])

        # 1-itemset cant generate rule
        if k == 1:
            continue

        """
        Generate all possible rule from a itemset
        eg:
        itemset (1, 2, 4,)

        rules: 
            1, 2 -> 4
            1, 4 -> 2
            2, 4 -> 1    
            1 -> 2, 4 
            2 -> 1, 4
            4 -> 1, 2
               
        """
        for itemset, support_count in k_itemset.items():
            H_cur = [[x] for x in itemset]
            to_remove = []
            for h in H_cur:
                antecedent = tuple(set(sorted(set(itemset) - set(h))))
                consequent = tuple(set(sorted(h)))

                confidence = support_count / frequent_itemsets[k - 2][antecedent]
                if confidence >= min_confidence:
                    rule = {tuple([antecedent, consequent]): confidence}
                    rules.append(rule)
                else:
                    to_remove.append(h)

            H_cur = generate_candidate([h for h in H_cur if h not in to_remove])

            for m in range(1, k - 1):
                if k > m + 1:
                    H_next = generate_candidate(H_cur)

                    for h in H_next:
                        antecedent = tuple(set(sorted(set(itemset) - set(h))))
                        consequent = tuple(set(sorted(h)))

                        confidence =  support_count / (frequent_itemsets[k - m - 2][antecedent])
                        
                        if confidence > min_confidence:
                            rule = {tuple([antecedent, consequent]): confidence}
                            rules.append(rule)                            
                        else:
                            to_remove.append(h)
                        
                        H_next = [x for x in H_next if x not in to_remove]
                        H_cur = H_next
                else:
                    break

    return rules

# %%
fi= generate_frequent_itemsets(data_path, 0.005)

# %%
rules = generate_rules(frequent_itemsets, 0.1)

# %%
adult_data_path = "/home/haianh/grad_project/ml-learning/data/adult.data"

grocerydata = "/home/haianh/grad_project/ml-learning/association-rule-mining-apriori/data/groceries.csv"

letter_data_path = "/home/haianh/grad_project/ml-learning/data/letter-recognition.data"


# frequent_itemsets = generate_frequent_itemsets(grocerydata, min_sup=0.01)

# frequent_itemsets

# %%
from time import perf_counter
supports = [0.1, 0.05, 0.03, 0.01]

for sup in supports:
    start = perf_counter()
    frequent_itemsets = generate_frequent_itemsets(letter_data_path, min_sup=sup)
    end = perf_counter()
    print(f"Support at {sup} takes: {end-start} seconds")

# %%
from time import perf_counter

def timeit(func):
    def timing_wrapper(*arg, **kwargs):
        start = perf_counter()
        value = func(*arg, **kwargs)
        end = perf_counter()
        print(f"{func.__name__} executed in {end-start} seconds")
        return value
    return timing_wrapper

@timeit
def add(a, b):
    return a + b

# %%
@timeit
def generate_candidate(list_k_item_candidtates: list):
    """
    Generate k+1 itemset candidate from list of k-item set candidate
    
    Eg:
        [
            [1, 2, 3],
            [1, 2, 4],
            [1, 2, 5],
        ]
        -->
        [
            [1, 2, 3, 4], 
            [1, 2, 3, 5],
            [1, 2, 4, 5],        
        ]
    
    
    """
    n = len(list_k_item_candidtates)
    new_candidates = []

    for i in range(n):
        for j in range(i + 1, n):
            candidate_a = list_k_item_candidtates[i]
            candidate_b = list_k_item_candidtates[j]

            if candidate_a[:-1] == candidate_b[:-1]:
                temp_candidate = []
                temp_candidate.extend(candidate_a)
                temp_candidate.append(candidate_b[-1])
                temp_candidate = sorted(temp_candidate)
                new_candidates.append(temp_candidate)
    
    return new_candidates

# %%
@timeit
def gen_by_comb(ilist):
    s = set()
    for li in ilist:
        s = s.union(set(li))
    return list(combinations(s, len(ilist[0]) + 1))

# %%
import random

# Generate a list of random integers
def generate_random_integers(n, min_value, max_value):
  """Generates a list of `n` random integers in the range `[min_value, max_value]`.

  Args:
    n: The number of random integers to generate.
    min_value: The minimum value of the random integers.
    max_value: The maximum value of the random integers.

  Returns:
    A list of `n` random integers.
  """
  random_integers = []
  for i in range(n):
    random_integers.append(random.randint(min_value, max_value))
  return random_integers

# Generate a list of random integer lists
def generate_random_integer_lists(n, m, min_value, max_value):
  """Generates a list of `n` lists of `m` random integers in the range `[min_value, max_value]`.

  Args:
    n: The number of lists to generate.
    m: The number of random integers in each list.
    min_value: The minimum value of the random integers.
    max_value: The maximum value of the random integers.

  Returns:
    A list of `n` lists of `m` random integers.
  """
  random_integer_lists = []
  for i in range(n):
    random_integer_lists.append(generate_random_integers(m, min_value, max_value))
  return random_integer_lists

# Example
print(generate_random_integer_lists(3, 5, 1, 10))
# Out:
# [[10, 8, 8, 3, 7], [8, 9, 2, 8, 3], [7, 8, 9, 4, 3]]

# %%
@timeit
def optimized_generate_frequent_itemsets(data_path, min_sup = 0.1) -> list[dict]:
    transactions, items = read(data_path)
    
    one_itemset = [[item] for item in items]

    temp_candidate_support =  get_support(one_itemset, transactions)

    final_candidate_support = []

    min_support_count = min_sup * len(transactions)
    candidate_support = {}

    # prune candidates which does not meet minimum support 
    for candidate in temp_candidate_support.keys():
        if temp_candidate_support[candidate] >= min_support_count:
            candidate_support[tuple(sorted(candidate))] = temp_candidate_support[candidate]

    final_candidate_support.append(candidate_support)

    # Generate k+1 itemset from list of k-itemset
    while(len(candidate_support)):
        current_candidates = gen_by_comb(list(candidate_support.keys()))
        
        if(len(current_candidates)):

            temp_dict_candidate_support = get_support(current_candidates, transactions)
            
            candidate_support = {}
            for candidate in temp_dict_candidate_support.keys():
                if temp_dict_candidate_support[candidate] >= min_support_count:
                    candidate_support[tuple(sorted(candidate))] = temp_dict_candidate_support[candidate]
            
            if len(candidate_support):
                final_candidate_support.append(candidate_support)

        else:
            break
    
    return final_candidate_support

# %%
@timeit
def generate_frequent_itemsets(data_path, min_sup = 0.1) -> list[dict]:
    transactions, items = read(data_path)
    
    one_itemset = [[item] for item in items]

    temp_candidate_support =  get_support(one_itemset, transactions)

    final_candidate_support = []

    min_support_count = min_sup * len(transactions)
    candidate_support = {}

    # prune candidates which does not meet minimum support 
    for candidate in temp_candidate_support.keys():
        if temp_candidate_support[candidate] >= min_support_count:
            candidate_support[tuple(sorted(candidate))] = temp_candidate_support[candidate]

    final_candidate_support.append(candidate_support)

    # Generate k+1 itemset from list of k-itemset
    while(len(candidate_support)):
        current_candidates = generate_candidate(list(candidate_support.keys()))
        
        if(len(current_candidates)):

            temp_dict_candidate_support = get_support(current_candidates, transactions)
            
            candidate_support = {}
            for candidate in temp_dict_candidate_support.keys():
                if temp_dict_candidate_support[candidate] >= min_support_count:
                    candidate_support[tuple(sorted(candidate))] = temp_dict_candidate_support[candidate]
            
            if len(candidate_support):
                final_candidate_support.append(candidate_support)

        else:
            break
    
    return final_candidate_support

# %%
generate_frequent_itemsets(data_path, min_sup=0.005)
# Out:
# generate_candidate executed in 0.005890868000278715 seconds
# generate_candidate executed in 0.055957337000108964 seconds
# generate_candidate executed in 0.009878055000626773 seconds
# generate_candidate executed in 3.0019000405445695e-05 seconds
# [{('citrus fruit',): 814,
#   ('margarine',): 576,
#   ('semi-finished bread',): 174,
#   ('coffee',): 571,
#   ('tropical fruit',): 1032,
#   ('yogurt',): 1372,
#   ('whole milk',): 2513,
#   ('cream cheese',): 390,
#   ('pip fruit',): 744,
#   ('condensed milk',): 101,
#   ('long life bakery product',): 368,
#   ('other vegetables',): 1903,
#   ('butter',): 545,
#   ('rice',): 75,
#   ('rolls/buns',): 1809,
#   ('UHT-milk',): 329,
#   ('bottled beer',): 792,
#   ('liquor (appetizer)',): 78,
#   ('potted plants',): 170,
#   ('cereals',): 56,
#   ('bottled water',): 1087,
#   ('chocolate',): 488,
#   ('white bread',): 414,
#   ('curd',): 524,
#   ('dishes',): 173,
#   ('flour',): 171,
#   ('beef',): 516,
#   ('frankfurter',): 580,
#   ('soda',): 1715,
#   ('chicken',): 422,
#   ('fruit/vegetable juice',): 711,
#   ('newspapers',): 785,
#   ('sugar',): 333,
#   ('packaged fruit/vegetables',): 128,
#   ('specialty bar',): 269,
#   ('butter milk',): 275,
#   ('pastry',): 875,
#   ('detergent',): 189,
#   ('processed cheese',): 163,
#   ('candy',): 294,
#   ('frozen dessert',): 106,
#   ('root vegetables',): 1072,
#   ('salty snack',): 372,
#   ('sweet spreads',): 89,
#   ('waffles',): 378,
#   ('canned beer',): 764,
#   ('sausage',): 924,
#   ('brown bread',): 638,
#   ('shopping bags',): 969,
#   ('beverages',): 256,
#   ('hamburger meat',): 327,
#   ('hygiene articles',): 324,
#   ('napkins',): 515,
#   ('spices',): 51,
#   ('berries',): 327,
#   ('pork',): 567,
#   ('whipped/sour cream',): 705,
#   ('grapes',): 220,
#   ('dessert',): 365,
#   ('zwieback',): 68,
#   ('domestic eggs',): 624,
#   ('spread cheese',): 110,
#   ('misc. beverages',): 279,
#   ('hard cheese',): 241,
#   ('cat food',): 229,
#   ('ham',): 256,
#   ('baking powder',): 174,
#   ('turkey',): 80,
#   ('pickled vegetables',): 176,
#   ('chewing gum',): 207,
#   ('chocolate marshmallow',): 89,
#   ('oil',): 276,
#   ('ice cream',): 246,
#   ('canned fish',): 148,
#   ('frozen vegetables',): 473,
#   ('seasonal products',): 140,
#   ('curd cheese',): 50,
#   ('red/blush wine',): 189,
#   ('frozen potato products',): 83,
#   ('candles',): 88,
#   ('flower (seeds)',): 102,
#   ('specialty chocolate',): 299,
#   ('sparkling wine',): 55,
#   ('salt',): 106,
#   ('frozen meals',): 279,
#   ('canned vegetables',): 106,
#   ('onions',): 305,
#   ('herbs',): 160,
#   ('white wine',): 187,
#   ('photo/film',): 91,
#   ('sliced cheese',): 241,
#   ('pasta',): 148,
#   ('softener',): 54,
#   ('cling film/bags',): 112,
#   ('Instant food products',): 79,
#   ('soft cheese',): 168,
#   ('dental care',): 57,
#   ('popcorn',): 71,
#   ('cake bar',): 130,
#   ('specialty cheese',): 84,
#   ('finished products',): 64,
#   ('dog food',): 84,
#   ('frozen fish',): 115,
#   ('cleaner',): 50,
#   ('female sanitary products',): 60,
#   ('dish cleaner',): 103,
#   ('meat',): 254,
#   ('mustard',): 118,
#   ('house keeping products',): 82,
#   ('liquor',): 109,
#   ('pet care',): 93,
#   ('soups',): 67,
#   ('sauces',): 54,
#   ('vinegar',): 64,
#   ('instant coffee',): 73,
#   ('roll products',): 101,
#   ('mayonnaise',): 90,
#   ('liver loaf',): 50,
#   ('kitchen towels',): 59,
#   ('jam',): 53},
#  {('citrus fruit', 'margarine'): 78,
#   ('coffee', 'tropical fruit'): 70,
#   ('coffee', 'yogurt'): 96,
#   ('tropical fruit', 'yogurt'): 288,
#   ('cream cheese', 'yogurt'): 122,
#   ('pip fruit', 'yogurt'): 177,
#   ('cream cheese', 'pip fruit'): 60,
#   ('long life bakery product', 'whole milk'): 133,
#   ('other vegetables', 'whole milk'): 736,
#   ('long life bakery product', 'other vegetables'): 105,
#   ('whole milk', 'yogurt'): 551,
#   ('butter', 'yogurt'): 144,
#   ('butter', 'whole milk'): 271,
#   ('other vegetables', 'rolls/buns'): 419,
#   ('UHT-milk', 'other vegetables'): 80,
#   ('bottled beer', 'other vegetables'): 159,
#   ('UHT-milk', 'rolls/buns'): 63,
#   ('bottled beer', 'rolls/buns'): 134,
#   ('other vegetables', 'tropical fruit'): 353,
#   ('bottled water', 'tropical fruit'): 182,
#   ('chocolate', 'tropical fruit'): 80,
#   ('tropical fruit', 'white bread'): 86,
#   ('bottled water', 'other vegetables'): 244,
#   ('chocolate', 'other vegetables'): 125,
#   ('other vegetables', 'white bread'): 135,
#   ('bottled water', 'chocolate'): 57,
#   ('citrus fruit', 'tropical fruit'): 196,
#   ('citrus fruit', 'yogurt'): 213,
#   ('citrus fruit', 'whole milk'): 300,
#   ('butter', 'citrus fruit'): 90,
#   ('bottled water', 'citrus fruit'): 133,
#   ('citrus fruit', 'curd'): 70,
#   ('tropical fruit', 'whole milk'): 416,
#   ('butter', 'tropical fruit'): 98,
#   ('curd', 'tropical fruit'): 101,
#   ('bottled water', 'yogurt'): 226,
#   ('curd', 'yogurt'): 170,
#   ('bottled water', 'whole milk'): 338,
#   ('curd', 'whole milk'): 257,
#   ('dishes', 'whole milk'): 52,
#   ('flour', 'whole milk'): 83,
#   ('bottled water', 'butter'): 88,
#   ('butter', 'curd'): 67,
#   ('bottled water', 'curd'): 60,
#   ('frankfurter', 'rolls/buns'): 189,
#   ('rolls/buns', 'soda'): 377,
#   ('frankfurter', 'soda'): 111,
#   ('chicken', 'tropical fruit'): 63,
#   ('butter', 'fruit/vegetable juice'): 79,
#   ('butter', 'newspapers'): 57,
#   ('fruit/vegetable juice', 'newspapers'): 81,
#   ('cream cheese', 'tropical fruit'): 71,
#   ('newspapers', 'tropical fruit'): 116,
#   ('rolls/buns', 'tropical fruit'): 242,
#   ('candy', 'tropical fruit'): 53,
#   ('root vegetables', 'tropical fruit'): 207,
#   ('salty snack', 'tropical fruit'): 55,
#   ('tropical fruit', 'waffles'): 60,
#   ('flour', 'other vegetables'): 62,
#   ('candy', 'other vegetables'): 68,
#   ('other vegetables', 'root vegetables'): 466,
#   ('other vegetables', 'salty snack'): 106,
#   ('other vegetables', 'waffles'): 99,
#   ('candy', 'rolls/buns'): 70,
#   ('rolls/buns', 'root vegetables'): 239,
#   ('rolls/buns', 'waffles'): 90,
#   ('root vegetables', 'waffles'): 65,
#   ('bottled water', 'canned beer'): 79,
#   ('chocolate', 'rolls/buns'): 116,
#   ('rolls/buns', 'sausage'): 301,
#   ('chocolate', 'soda'): 133,
#   ('chocolate', 'sausage'): 65,
#   ('sausage', 'soda'): 239,
#   ('fruit/vegetable juice', 'soda'): 181,
#   ('newspapers', 'soda'): 144,
#   ('canned beer', 'soda'): 136,
#   ('brown bread', 'soda'): 124,
#   ('shopping bags', 'soda'): 242,
#   ('brown bread', 'fruit/vegetable juice'): 82,
#   ('fruit/vegetable juice', 'shopping bags'): 105,
#   ('brown bread', 'newspapers'): 75,
#   ('newspapers', 'shopping bags'): 68,
#   ('canned beer', 'shopping bags'): 112,
#   ('brown bread', 'shopping bags'): 91,
#   ('beverages', 'yogurt'): 54,
#   ('hamburger meat', 'other vegetables'): 136,
#   ('hygiene articles', 'other vegetables'): 94,
#   ('napkins', 'other vegetables'): 142,
#   ('bottled water', 'rolls/buns'): 238,
#   ('hamburger meat', 'rolls/buns'): 85,
#   ('hygiene articles', 'rolls/buns'): 58,
#   ('napkins', 'rolls/buns'): 115,
#   ('bottled water', 'hygiene articles'): 56,
#   ('bottled water', 'napkins'): 85,
#   ('hygiene articles', 'napkins'): 60,
#   ('sugar', 'whole milk'): 148,
#   ('root vegetables', 'whole milk'): 481,
#   ('beverages', 'whole milk'): 67,
#   ('other vegetables', 'sugar'): 106,
#   ('beverages', 'other vegetables'): 51,
#   ('root vegetables', 'sugar'): 63,
#   ('soda', 'whole milk'): 394,
#   ('berries', 'whole milk'): 116,
#   ('pork', 'whole milk'): 218,
#   ('whipped/sour cream', 'whole milk'): 317,
#   ('other vegetables', 'soda'): 322,
#   ('berries', 'other vegetables'): 101,
#   ('other vegetables', 'pork'): 213,
#   ('other vegetables', 'whipped/sour cream'): 284,
#   ('berries', 'soda'): 72,
#   ('pork', 'soda'): 117,
#   ('soda', 'whipped/sour cream'): 114,
#   ('berries', 'whipped/sour cream'): 89,
#   ('pork', 'whipped/sour cream'): 81,
#   ('pastry', 'soda'): 207,
#   ('dessert', 'whole milk'): 135,
#   ('dessert', 'other vegetables'): 114,
#   ('dessert', 'root vegetables'): 57,
#   ('citrus fruit', 'newspapers'): 82,
#   ('rolls/buns', 'specialty bar'): 55,
#   ('canned beer', 'rolls/buns'): 111,
#   ('rolls/buns', 'shopping bags'): 192,
#   ('soda', 'specialty bar'): 71,
#   ('canned beer', 'sausage'): 62,
#   ('sausage', 'shopping bags'): 154,
#   ('coffee', 'whole milk'): 184,
#   ('coffee', 'soda'): 98,
#   ('coffee', 'pastry'): 68,
#   ('coffee', 'root vegetables'): 72,
#   ('soda', 'tropical fruit'): 205,
#   ('pastry', 'tropical fruit'): 130,
#   ('brown bread', 'tropical fruit'): 105,
#   ('domestic eggs', 'tropical fruit'): 112,
#   ('soda', 'yogurt'): 269,
#   ('sugar', 'yogurt'): 68,
#   ('pastry', 'yogurt'): 174,
#   ('candy', 'yogurt'): 54,
#   ('root vegetables', 'yogurt'): 254,
#   ('waffles', 'yogurt'): 74,
#   ('brown bread', 'yogurt'): 143,
#   ('domestic eggs', 'yogurt'): 141,
#   ('pastry', 'whole milk'): 327,
#   ('candy', 'whole milk'): 81,
#   ('waffles', 'whole milk'): 125,
#   ('brown bread', 'whole milk'): 248,
#   ('domestic eggs', 'whole milk'): 295,
#   ('soda', 'sugar'): 72,
#   ('candy', 'soda'): 85,
#   ('root vegetables', 'soda'): 183,
#   ('soda', 'waffles'): 94,
#   ('domestic eggs', 'soda'): 122,
#   ('pastry', 'sugar'): 51,
#   ('pastry', 'root vegetables'): 108,
#   ('pastry', 'waffles'): 69,
#   ('brown bread', 'pastry'): 95,
#   ('domestic eggs', 'pastry'): 89,
#   ('brown bread', 'root vegetables'): 100,
#   ('domestic eggs', 'root vegetables'): 141,
#   ('brown bread', 'domestic eggs'): 67,
#   ('berries', 'yogurt'): 104,
#   ('rolls/buns', 'yogurt'): 338,
#   ('newspapers', 'yogurt'): 151,
#   ('butter milk', 'yogurt'): 84,
#   ('cream cheese', 'rolls/buns'): 98,
#   ('bottled water', 'cream cheese'): 58,
#   ('cream cheese', 'soda'): 67,
#   ('newspapers', 'rolls/buns'): 194,
#   ('butter milk', 'rolls/buns'): 75,
#   ('bottled water', 'soda'): 285,
#   ('bottled water', 'newspapers'): 111,
#   ('bottled water', 'pastry'): 88,
#   ('long life bakery product', 'rolls/buns'): 78,
#   ('long life bakery product', 'root vegetables'): 52,
#   ('long life bakery product', 'whipped/sour cream'): 57,
#   ('butter', 'other vegetables'): 197,
#   ('curd', 'other vegetables'): 169,
#   ('hard cheese', 'other vegetables'): 93,
#   ('butter', 'rolls/buns'): 132,
#   ('butter', 'root vegetables'): 127,
#   ('butter', 'whipped/sour cream'): 100,
#   ('curd', 'rolls/buns'): 99,
#   ('rolls/buns', 'whipped/sour cream'): 144,
#   ('hard cheese', 'rolls/buns'): 58,
#   ('UHT-milk', 'bottled water'): 72,
#   ('bottled water', 'root vegetables'): 154,
#   ('bottled water', 'whipped/sour cream'): 86,
#   ('curd', 'root vegetables'): 107,
#   ('curd', 'whipped/sour cream'): 103,
#   ('root vegetables', 'whipped/sour cream'): 168,
#   ('hard cheese', 'root vegetables'): 55,
#   ('newspapers', 'sausage'): 79,
#   ('grapes', 'whole milk'): 72,
#   ('ham', 'whole milk'): 113,
#   ('grapes', 'other vegetables'): 89,
#   ('ham', 'other vegetables'): 90,
#   ('margarine', 'tropical fruit'): 92,
#   ('margarine', 'other vegetables'): 194,
#   ('curd', 'margarine'): 62,
#   ('fruit/vegetable juice', 'margarine'): 61,
#   ('brown bread', 'margarine'): 64,
#   ('domestic eggs', 'margarine'): 82,
#   ('other vegetables', 'semi-finished bread'): 51,
#   ('fruit/vegetable juice', 'tropical fruit'): 135,
#   ('fruit/vegetable juice', 'other vegetables'): 207,
#   ('brown bread', 'other vegetables'): 184,
#   ('domestic eggs', 'other vegetables'): 219,
#   ('baking powder', 'other vegetables'): 72,
#   ('curd', 'domestic eggs'): 64,
#   ('domestic eggs', 'fruit/vegetable juice'): 79,
#   ('processed cheese', 'whole milk'): 69,
#   ('pickled vegetables', 'whole milk'): 70,
#   ('processed cheese', 'soda'): 52,
#   ('curd', 'pastry'): 74,
#   ('oil', 'rolls/buns'): 50,
#   ('beef', 'rolls/buns'): 134,
#   ('ham', 'rolls/buns'): 68,
#   ('beef', 'whipped/sour cream'): 66,
#   ('rolls/buns', 'sugar'): 69,
#   ('pastry', 'rolls/buns'): 206,
#   ('detergent', 'whole milk'): 88,
#   ('salty snack', 'whole milk'): 110,
#   ('frozen vegetables', 'whole milk'): 201,
#   ('detergent', 'other vegetables'): 63,
#   ('canned fish', 'other vegetables'): 50,
#   ('frozen vegetables', 'other vegetables'): 175,
#   ('pastry', 'sausage'): 123,
#   ('beef', 'whole milk'): 209,
#   ('sausage', 'whole milk'): 294,
#   ('beef', 'sausage'): 55,
#   ('frankfurter', 'tropical fruit'): 93,
#   ('brown bread', 'rolls/buns'): 124,
#   ('brown bread', 'frankfurter'): 70,
#   ('curd', 'sausage'): 75,
#   ('pip fruit', 'tropical fruit'): 201,
#   ('berries', 'tropical fruit'): 66,
#   ('pip fruit', 'whole milk'): 296,
#   ('rolls/buns', 'whole milk'): 557,
#   ('chocolate', 'whole milk'): 164,
#   ('pip fruit', 'rolls/buns'): 137,
#   ('chocolate', 'pip fruit'): 60,
#   ('berries', 'rolls/buns'): 65,
#   ('margarine', 'whole milk'): 238,
#   ('butter', 'margarine'): 66,
#   ('specialty chocolate', 'whole milk'): 79,
#   ('citrus fruit', 'frankfurter'): 64,
#   ('citrus fruit', 'domestic eggs'): 102,
#   ('frankfurter', 'whole milk'): 202,
#   ('newspapers', 'whole milk'): 269,
#   ('oil', 'whole milk'): 111,
#   ('domestic eggs', 'frankfurter'): 69,
#   ('domestic eggs', 'newspapers'): 68,
#   ('citrus fruit', 'pastry'): 96,
#   ('butter milk', 'whole milk'): 114,
#   ('bottled beer', 'bottled water'): 155,
#   ('bottled beer', 'fruit/vegetable juice'): 69,
#   ('bottled water', 'fruit/vegetable juice'): 140,
#   ('bottled beer', 'soda'): 167,
#   ('margarine', 'rolls/buns'): 145,
#   ('margarine', 'root vegetables'): 109,
#   ('frozen vegetables', 'margarine'): 50,
#   ('fruit/vegetable juice', 'whole milk'): 262,
#   ('fruit/vegetable juice', 'rolls/buns'): 143,
#   ('domestic eggs', 'rolls/buns'): 154,
#   ('frozen vegetables', 'rolls/buns'): 100,
#   ('fruit/vegetable juice', 'root vegetables'): 118,
#   ('frozen vegetables', 'fruit/vegetable juice'): 77,
#   ('oil', 'root vegetables'): 69,
#   ('frozen vegetables', 'root vegetables'): 114,
#   ('domestic eggs', 'frozen vegetables'): 51,
#   ('onions', 'root vegetables'): 93,
#   ('sausage', 'yogurt'): 193,
#   ('onions', 'yogurt'): 71,
#   ('onions', 'rolls/buns'): 67,
#   ('root vegetables', 'sausage'): 147,
#   ('fruit/vegetable juice', 'salty snack'): 59,
#   ('citrus fruit', 'cream cheese'): 56,
#   ('citrus fruit', 'coffee'): 63,
#   ('chocolate', 'citrus fruit'): 63,
#   ('berries', 'citrus fruit'): 53,
#   ('citrus fruit', 'pork'): 64,
#   ('citrus fruit', 'whipped/sour cream'): 107,
#   ('citrus fruit', 'onions'): 55,
#   ('coffee', 'whipped/sour cream'): 60,
#   ('onions', 'whipped/sour cream'): 50,
#   ('rolls/buns', 'sliced cheese'): 75,
#   ('fruit/vegetable juice', 'sausage'): 99,
#   ('shopping bags', 'waffles'): 54,
#   ('brown bread', 'sausage'): 105,
#   ('sausage', 'sliced cheese'): 69,
#   ('citrus fruit', 'other vegetables'): 284,
#   ('chicken', 'citrus fruit'): 68,
#   ('citrus fruit', 'root vegetables'): 174,
#   ('chicken', 'other vegetables'): 176,
#   ('oil', 'other vegetables'): 98,
#   ('butter', 'chicken'): 57,
#   ('chicken', 'root vegetables'): 107,
#   ('hamburger meat', 'root vegetables'): 61,
#   ('misc. beverages', 'soda'): 72,
#   ('specialty bar', 'whole milk'): 64,
#   ('pork', 'rolls/buns'): 111,
#   ('pastry', 'pork'): 62,
#   ('pork', 'sausage'): 64,
#   ('bottled water', 'frankfurter'): 72,
#   ('coffee', 'fruit/vegetable juice'): 59,
#   ('coffee', 'sausage'): 68,
#   ('coffee', 'shopping bags'): 92,
#   ('bottled beer', 'yogurt'): 91,
#   ('fruit/vegetable juice', 'yogurt'): 184,
#   ('shopping bags', 'yogurt'): 150,
#   ('napkins', 'yogurt'): 121,
#   ('bottled beer', 'whole milk'): 201,
#   ('shopping bags', 'whole milk'): 241,
#   ('napkins', 'whole milk'): 194,
#   ('bottled beer', 'sausage'): 77,
#   ('bottled beer', 'shopping bags'): 55,
#   ('bottled beer', 'napkins'): 51,
#   ('fruit/vegetable juice', 'napkins'): 68,
#   ('napkins', 'sausage'): 66,
#   ('napkins', 'shopping bags'): 71,
#   ('beef', 'citrus fruit'): 83,
#   ('brown bread', 'citrus fruit'): 82,
#   ('beef', 'root vegetables'): 171,
#   ('berries', 'root vegetables'): 65,
#   ('waffles', 'whipped/sour cream'): 50,
#   ('dishes', 'other vegetables'): 59,
#   ('frankfurter', 'other vegetables'): 162,
#   ('other vegetables', 'sausage'): 265,
#   ('other vegetables', 'pickled vegetables'): 63,
#   ('bottled beer', 'frankfurter'): 53,
#   ('bottled beer', 'root vegetables'): 95,
#   ('frankfurter', 'root vegetables'): 100,
#   ('frankfurter', 'sausage'): 99,
#   ('bottled water', 'margarine'): 101,
#   ('margarine', 'newspapers'): 70,
#   ('dessert', 'rolls/buns'): 67,
#   ('bottled water', 'dessert'): 51,
#   ('bottled water', 'frozen vegetables'): 61,
#   ('hamburger meat', 'whole milk'): 145,
#   ('hamburger meat', 'soda'): 57,
#   ('frozen vegetables', 'soda'): 85,
#   ('cream cheese', 'whole milk'): 162,
#   ('margarine', 'pastry'): 67,
#   ('margarine', 'shopping bags'): 56,
#   ('coffee', 'other vegetables'): 132,
#   ('long life bakery product', 'pastry'): 58,
#   ('long life bakery product', 'shopping bags'): 53,
#   ('other vegetables', 'pastry'): 222,
#   ('other vegetables', 'shopping bags'): 228,
#   ('pastry', 'shopping bags'): 117,
#   ('long life bakery product', 'sausage'): 53,
#   ('citrus fruit', 'pip fruit'): 136,
#   ('citrus fruit', 'fruit/vegetable juice'): 102,
#   ('citrus fruit', 'sausage'): 111,
#   ('citrus fruit', 'hygiene articles'): 52,
#   ('sausage', 'tropical fruit'): 137,
#   ('hygiene articles', 'tropical fruit'): 66,
#   ('hygiene articles', 'whole milk'): 126,
#   ('misc. beverages', 'whole milk'): 69,
#   ('hard cheese', 'whole milk'): 99,
#   ('cream cheese', 'fruit/vegetable juice'): 56,
#   ('cream cheese', 'sausage'): 55,
#   ('cream cheese', 'domestic eggs'): 50,
#   ('frankfurter', 'pip fruit'): 71,
#   ('fruit/vegetable juice', 'pip fruit'): 94,
#   ('pip fruit', 'sausage'): 106,
#   ('domestic eggs', 'pip fruit'): 85,
#   ('frankfurter', 'fruit/vegetable juice'): 52,
#   ('domestic eggs', 'sausage'): 94,
#   ('hard cheese', 'sausage'): 51,
#   ('frankfurter', 'margarine'): 63,
#   ('margarine', 'sausage'): 70,
#   ('canned beer', 'other vegetables'): 89,
#   ('misc. beverages', 'other vegetables'): 55,
#   ('baking powder', 'whole milk'): 91,
#   ('soft cheese', 'whole milk'): 74,
#   ('other vegetables', 'pip fruit'): 257,
#   ('frozen vegetables', 'pip fruit'): 72,
#   ('other vegetables', 'soft cheese'): 70,
#   ('rolls/buns', 'soft cheese'): 53,
#   ('frankfurter', 'frozen vegetables'): 50,
#   ('citrus fruit', 'rolls/buns'): 165,
#   ('bottled water', 'onions'): 58,
#   ('cake bar', 'whole milk'): 55,
#   ('chocolate', 'shopping bags'): 80,
#   ('sausage', 'white bread'): 71,
#   ('dessert', 'sausage'): 58,
#   ('other vegetables', 'yogurt'): 427,
#   ('dessert', 'yogurt'): 97,
#   ('curd', 'dessert'): 51,
#   ('frozen vegetables', 'yogurt'): 122,
#   ('soft cheese', 'yogurt'): 59,
#   ('chewing gum', 'soda'): 53,
#   ('bottled beer', 'tropical fruit'): 81,
#   ('ham', 'tropical fruit'): 53,
#   ('white bread', 'whole milk'): 168,
#   ('bottled beer', 'brown bread'): 51,
#   ('fruit/vegetable juice', 'white bread'): 73,
#   ('ham', 'white bread'): 50,
#   ('chocolate', 'waffles'): 57,
#   ('curd', 'soda'): 80,
#   ('curd', 'shopping bags'): 53,
#   ('salty snack', 'soda'): 92,
#   ('dessert', 'soda'): 97,
#   ('salty snack', 'shopping bags'): 59,
#   ('dessert', 'shopping bags'): 61,
#   ('bottled water', 'shopping bags'): 108,
#   ('ice cream', 'other vegetables'): 50,
#   ('tropical fruit', 'whipped/sour cream'): 136,
#   ('frozen meals', 'tropical fruit'): 54,
#   ('sliced cheese', 'tropical fruit'): 52,
#   ('white bread', 'yogurt'): 89,
#   ('frankfurter', 'yogurt'): 110,
#   ('whipped/sour cream', 'yogurt'): 204,
#   ('ham', 'yogurt'): 66,
#   ('frozen meals', 'yogurt'): 61,
#   ('sliced cheese', 'yogurt'): 79,
#   ('frozen meals', 'whole milk'): 97,
#   ('sliced cheese', 'whole milk'): 106,
#   ('cream cheese', 'other vegetables'): 135,
#   ('cream cheese', 'curd'): 50,
#   ('cream cheese', 'root vegetables'): 74,
#   ('cream cheese', 'whipped/sour cream'): 63,
#   ('butter', 'pip fruit'): 72,
#   ('bottled beer', 'pip fruit'): 58,
#   ('pip fruit', 'white bread'): 65,
#   ('curd', 'pip fruit'): 77,
#   ('pip fruit', 'root vegetables'): 153,
#   ('pip fruit', 'whipped/sour cream'): 91,
#   ('frozen meals', 'other vegetables'): 74,
#   ('other vegetables', 'sliced cheese'): 89,
#   ('bottled beer', 'butter'): 57,
#   ('butter', 'domestic eggs'): 95,
#   ('frankfurter', 'white bread'): 51,
#   ('root vegetables', 'white bread'): 78,
#   ('whipped/sour cream', 'white bread'): 54,
#   ('domestic eggs', 'white bread'): 57,
#   ('frankfurter', 'whipped/sour cream'): 61,
#   ('fruit/vegetable juice', 'whipped/sour cream'): 89,
#   ('root vegetables', 'sliced cheese'): 55,
#   ('domestic eggs', 'whipped/sour cream'): 98,
#   ('cream cheese', 'shopping bags'): 55,
#   ('shopping bags', 'tropical fruit'): 133,
#   ('frankfurter', 'shopping bags'): 81,
#   ('pip fruit', 'pork'): 60,
#   ('beef', 'pork'): 75,
#   ('margarine', 'sugar'): 54,
#   ('pork', 'root vegetables'): 134,
#   ('hygiene articles', 'yogurt'): 72,
#   ('butter', 'soda'): 87,
#   ('hygiene articles', 'soda'): 69,
#   ('UHT-milk', 'soda'): 75,
#   ('beef', 'margarine'): 61,
#   ('margarine', 'pork'): 63,
#   ('beef', 'other vegetables'): 194,
#   ('butter milk', 'other vegetables'): 102,
#   ('beverages', 'rolls/buns'): 53,
#   ('sausage', 'whipped/sour cream'): 89,
#   ('sliced cheese', 'soda'): 50,
#   ('onions', 'tropical fruit'): 56,
#   ('root vegetables', 'shopping bags'): 126,
#   ('meat', 'other vegetables'): 98,
#   ('meat', 'rolls/buns'): 68,
#   ('bottled water', 'brown bread'): 81,
#   ('mustard', 'whole milk'): 51,
#   ('butter', 'sausage'): 85,
#   ('salty snack', 'sausage'): 52,
#   ('herbs', 'whole milk'): 76,
#   ('herbs', 'other vegetables'): 76,
#   ('herbs', 'root vegetables'): 69,
#   ('margarine', 'whipped/sour cream'): 67,
#   ('semi-finished bread', 'whole milk'): 70,
#   ('citrus fruit', 'napkins'): 75,
#   ('napkins', 'whipped/sour cream'): 71,
#   ('curd', 'newspapers'): 56,
#   ('newspapers', 'pastry'): 83,
#   ('bottled water', 'misc. beverages'): 52,
#   ('napkins', 'soda'): 118,
#   ('beef', 'butter'): 57,
#   ('beef', 'bottled water'): 61,
#   ('pork', 'shopping bags'): 63,
#   ('shopping bags', 'whipped/sour cream'): 78,
#   ('bottled water', 'pip fruit'): 104,
#   ('bottled water', 'sausage'): 118,
#   ('citrus fruit', 'soda'): 126,
#   ('chocolate', 'yogurt'): 91,
#   ('newspapers', 'other vegetables'): 190,
#   ('chocolate', 'newspapers'): 54,
#   ('other vegetables', 'specialty bar'): 55,
#   ('napkins', 'tropical fruit'): 99,
#   ('onions', 'whole milk'): 119,
#   ('pip fruit', 'soda'): 131,
#   ('napkins', 'pip fruit'): 66,
#   ('onions', 'other vegetables'): 140,
#   ('onions', 'soda'): 52,
#   ('domestic eggs', 'napkins'): 59,
#   ('meat', 'whole milk'): 98,
#   ('meat', 'soda'): 54,
#   ('meat', 'root vegetables'): 50,
#   ('butter milk', 'tropical fruit'): 54,
#   ('butter milk', 'root vegetables'): 50,
#   ('hygiene articles', 'root vegetables'): 53,
#   ('margarine', 'pip fruit'): 84,
#   ('brown bread', 'pip fruit'): 75,
#   ('margarine', 'yogurt'): 140,
#   ('hamburger meat', 'yogurt'): 64,
#   ('fruit/vegetable juice', 'pastry'): 84,
#   ('chicken', 'yogurt'): 82,
#   ('chicken', 'whole milk'): 173,
#   ('pasta', 'whole milk'): 60,
#   ('chicken', 'rolls/buns'): 95,
#   ('chicken', 'soda'): 82,
#   ('chicken', 'whipped/sour cream'): 71,
#   ('pastry', 'pip fruit'): 105,
#   ('bottled water', 'domestic eggs'): 90,
#   ('potted plants', 'whole milk'): 68,
#   ('citrus fruit', 'shopping bags'): 96,
#   ('canned beer', 'whole milk'): 87,
#   ('bottled water', 'chicken'): 52,
#   ('chicken', 'newspapers'): 51,
#   ('napkins', 'newspapers'): 61,
#   ('pork', 'yogurt'): 94,
#   ('oil', 'yogurt'): 52,
#   ('beef', 'yogurt'): 115,
#   ('canned beer', 'yogurt'): 53,
#   ('napkins', 'root vegetables'): 98,
#   ('pastry', 'white bread'): 55,
#   ('beef', 'pastry'): 62,
#   ('chicken', 'sausage'): 52,
#   ('brown bread', 'pork'): 55,
#   ('other vegetables', 'specialty chocolate'): 60,
#   ('soda', 'specialty chocolate'): 62,
#   ('hamburger meat', 'sausage'): 51,
#   ('meat', 'sausage'): 52,
#   ('brown bread', 'butter'): 57,
#   ('butter', 'pork'): 54,
#   ('frankfurter', 'pork'): 58,
#   ('frankfurter', 'pastry'): 82,
#   ('napkins', 'pastry'): 69,
#   ('pastry', 'whipped/sour cream'): 74,
#   ('cat food', 'whole milk'): 87,
#   ('cat food', 'other vegetables'): 64,
#   ('coffee', 'rolls/buns'): 108,
#   ('butter', 'frozen vegetables'): 57,
#   ('frozen vegetables', 'whipped/sour cream'): 78,
#   ('long life bakery product', 'yogurt'): 86,
#   ('fruit/vegetable juice', 'long life bakery product'): 61,
#   ('bottled beer', 'margarine'): 60,
#   ('pork', 'tropical fruit'): 84,
#   ('beef', 'domestic eggs'): 59,
#   ('citrus fruit', 'frozen vegetables'): 65,
#   ('beef', 'newspapers'): 63,
#   ('beef', 'tropical fruit'): 75,
#   ('beef', 'soda'): 80,
#   ('frozen vegetables', 'pork'): 63,
#   ('ice cream', 'whole milk'): 58,
#   ('frozen vegetables', 'sausage'): 59,
#   ('butter', 'pastry'): 75,
#   ('coffee', 'pip fruit'): 68,
#   ('butter milk', 'pip fruit'): 50,
#   ('chocolate', 'long life bakery product'): 52,
#   ('frozen meals', 'soda'): 61,
#   ('pip fruit', 'shopping bags'): 92,
#   ('soda', 'white bread'): 101,
#   ('bottled water', 'coffee'): 72,
#   ('newspapers', 'pork'): 65,
#   ('napkins', 'pork'): 51,
#   ('salty snack', 'yogurt'): 61,
#   ('shopping bags', 'white bread'): 73,
#   ('frozen vegetables', 'tropical fruit'): 86,
#   ('hygiene articles', 'shopping bags'): 51,
#   ('domestic eggs', 'shopping bags'): 89,
#   ('hard cheese', 'yogurt'): 63,
#   ('domestic eggs', 'pork'): 55,
#   ('bottled water', 'pork'): 73,
#   ('meat', 'yogurt'): 52,
#   ('newspapers', 'root vegetables'): 113,
#   ('long life bakery product', 'soda'): 75,
#   ('newspapers', 'pip fruit'): 66,
#   ('UHT-milk', 'yogurt'): 73,
#   ('other vegetables', 'processed cheese'): 54,
#   ('beef', 'fruit/vegetable juice'): 50,
#   ('grapes', 'tropical fruit'): 60,
#   ('long life bakery product', 'tropical fruit'): 62,
#   ('pastry', 'salty snack'): 51,
#   ('bottled beer', 'citrus fruit'): 60,
#   ('coffee', 'frankfurter'): 50,
#   ('chocolate', 'root vegetables'): 63,
#   ('margarine', 'soda'): 100,
#   ('bottled beer', 'pork'): 51,
#   ('chicken', 'pork'): 57,
#   ('chicken', 'domestic eggs'): 61,
#   ('chicken', 'frozen vegetables'): 66,
#   ('ice cream', 'soda'): 60,
#   ('newspapers', 'whipped/sour cream'): 71,
#   ('chewing gum', 'whole milk'): 50,
#   ('rolls/buns', 'specialty chocolate'): 55,
#   ('rolls/buns', 'white bread'): 64,
#   ('chocolate', 'fruit/vegetable juice'): 67,
#   ('chocolate', 'pastry'): 79,
#   ('salty snack', 'whipped/sour cream'): 51,
#   ('butter', 'chocolate'): 61,
#   ('dessert', 'tropical fruit'): 62,
#   ('dessert', 'fruit/vegetable juice'): 59,
#   ('dessert', 'pastry'): 53,
#   ('cat food', 'yogurt'): 61},
#  {('long life bakery product', 'other vegetables', 'whole milk'): 56,
#   ('butter', 'whole milk', 'yogurt'): 92,
#   ('bottled water', 'other vegetables', 'tropical fruit'): 61,
#   ('tropical fruit', 'whole milk', 'yogurt'): 149,
#   ('butter', 'citrus fruit', 'whole milk'): 50,
#   ('butter', 'tropical fruit', 'whole milk'): 61,
#   ('bottled water', 'tropical fruit', 'yogurt'): 70,
#   ('bottled water', 'tropical fruit', 'whole milk'): 79,
#   ('citrus fruit', 'tropical fruit', 'yogurt'): 62,
#   ('citrus fruit', 'tropical fruit', 'whole milk'): 89,
#   ('citrus fruit', 'whole milk', 'yogurt'): 101,
#   ('bottled water', 'citrus fruit', 'whole milk'): 58,
#   ('curd', 'tropical fruit', 'yogurt'): 52,
#   ('curd', 'tropical fruit', 'whole milk'): 64,
#   ('bottled water', 'whole milk', 'yogurt'): 95,
#   ('curd', 'whole milk', 'yogurt'): 99,
#   ('bottled water', 'butter', 'whole milk'): 53,
#   ('other vegetables', 'rolls/buns', 'tropical fruit'): 77,
#   ('other vegetables', 'rolls/buns', 'root vegetables'): 120,
#   ('other vegetables', 'root vegetables', 'tropical fruit'): 121,
#   ('rolls/buns', 'root vegetables', 'tropical fruit'): 58,
#   ('rolls/buns', 'sausage', 'soda'): 95,
#   ('bottled water', 'other vegetables', 'rolls/buns'): 72,
#   ('other vegetables', 'root vegetables', 'whole milk'): 228,
#   ('other vegetables', 'sugar', 'whole milk'): 62,
#   ('other vegetables', 'soda', 'whole milk'): 137,
#   ('other vegetables', 'pork', 'whole milk'): 100,
#   ('other vegetables', 'whipped/sour cream', 'whole milk'): 144,
#   ('soda', 'whipped/sour cream', 'whole milk'): 54,
#   ('rolls/buns', 'shopping bags', 'soda'): 62,
#   ('rolls/buns', 'sausage', 'shopping bags'): 59,
#   ('sausage', 'shopping bags', 'soda'): 56,
#   ('coffee', 'whole milk', 'yogurt'): 50,
#   ('root vegetables', 'tropical fruit', 'whole milk'): 118,
#   ('root vegetables', 'tropical fruit', 'yogurt'): 80,
#   ('brown bread', 'soda', 'whole milk'): 50,
#   ('root vegetables', 'whole milk', 'yogurt'): 143,
#   ('root vegetables', 'soda', 'whole milk'): 80,
#   ('soda', 'tropical fruit', 'whole milk'): 77,
#   ('soda', 'whole milk', 'yogurt'): 103,
#   ('pastry', 'soda', 'whole milk'): 81,
#   ('soda', 'tropical fruit', 'yogurt'): 65,
#   ('pastry', 'tropical fruit', 'whole milk'): 66,
#   ('brown bread', 'tropical fruit', 'whole milk'): 56,
#   ('domestic eggs', 'tropical fruit', 'whole milk'): 68,
#   ('pastry', 'whole milk', 'yogurt'): 90,
#   ('brown bread', 'whole milk', 'yogurt'): 70,
#   ('domestic eggs', 'whole milk', 'yogurt'): 76,
#   ('pastry', 'root vegetables', 'whole milk'): 56,
#   ('brown bread', 'root vegetables', 'whole milk'): 56,
#   ('domestic eggs', 'soda', 'whole milk'): 51,
#   ('domestic eggs', 'root vegetables', 'whole milk'): 84,
#   ('bottled water', 'rolls/buns', 'yogurt'): 70,
#   ('bottled water', 'soda', 'yogurt'): 73,
#   ('rolls/buns', 'soda', 'yogurt'): 85,
#   ('bottled water', 'rolls/buns', 'soda'): 67,
#   ('newspapers', 'rolls/buns', 'yogurt'): 50,
#   ('other vegetables', 'rolls/buns', 'whipped/sour cream'): 66,
#   ('bottled water', 'other vegetables', 'root vegetables'): 69,
#   ('other vegetables', 'root vegetables', 'whipped/sour cream'): 84,
#   ('butter', 'other vegetables', 'rolls/buns'): 56,
#   ('butter', 'other vegetables', 'root vegetables'): 65,
#   ('butter', 'other vegetables', 'whipped/sour cream'): 57,
#   ('curd', 'other vegetables', 'root vegetables'): 54,
#   ('curd', 'other vegetables', 'tropical fruit'): 52,
#   ('fruit/vegetable juice', 'other vegetables', 'tropical fruit'): 65,
#   ('frozen vegetables', 'other vegetables', 'whole milk'): 95,
#   ('pastry', 'rolls/buns', 'soda'): 53,
#   ('rolls/buns', 'tropical fruit', 'whole milk'): 108,
#   ('pip fruit', 'tropical fruit', 'whole milk'): 83,
#   ('pip fruit', 'rolls/buns', 'whole milk'): 61,
#   ('citrus fruit', 'domestic eggs', 'whole milk'): 56,
#   ('other vegetables', 'rolls/buns', 'whole milk'): 176,
#   ('bottled beer', 'bottled water', 'soda'): 50,
#   ('rolls/buns', 'root vegetables', 'whole milk'): 125,
#   ('domestic eggs', 'margarine', 'whole milk'): 51,
#   ('domestic eggs', 'rolls/buns', 'whole milk'): 65,
#   ('frozen vegetables', 'rolls/buns', 'whole milk'): 50,
#   ('frozen vegetables', 'root vegetables', 'whole milk'): 61,
#   ('margarine', 'rolls/buns', 'whole milk'): 78,
#   ('fruit/vegetable juice', 'rolls/buns', 'whole milk'): 55,
#   ('fruit/vegetable juice', 'root vegetables', 'whole milk'): 64,
#   ('rolls/buns', 'root vegetables', 'yogurt'): 71,
#   ('rolls/buns', 'sausage', 'yogurt'): 59,
#   ('root vegetables', 'sausage', 'yogurt'): 51,
#   ('citrus fruit', 'other vegetables', 'tropical fruit'): 89,
#   ('citrus fruit', 'root vegetables', 'tropical fruit'): 56,
#   ('butter', 'other vegetables', 'tropical fruit'): 54,
#   ('citrus fruit', 'other vegetables', 'root vegetables'): 102,
#   ('chicken', 'other vegetables', 'root vegetables'): 56,
#   ('rolls/buns', 'soda', 'whole milk'): 87,
#   ('rolls/buns', 'sausage', 'whole milk'): 92,
#   ('sausage', 'soda', 'whole milk'): 66,
#   ('pork', 'rolls/buns', 'whole milk'): 61,
#   ('pastry', 'rolls/buns', 'whole milk'): 84,
#   ('pastry', 'sausage', 'whole milk'): 56,
#   ('sausage', 'whole milk', 'yogurt'): 86,
#   ('fruit/vegetable juice', 'whole milk', 'yogurt'): 93,
#   ('bottled beer', 'whole milk', 'yogurt'): 51,
#   ('shopping bags', 'whole milk', 'yogurt'): 52,
#   ('napkins', 'whole milk', 'yogurt'): 60,
#   ('rolls/buns', 'whipped/sour cream', 'whole milk'): 77,
#   ('other vegetables', 'rolls/buns', 'sausage'): 87,
#   ('frankfurter', 'other vegetables', 'rolls/buns'): 55,
#   ('other vegetables', 'root vegetables', 'sausage'): 67,
#   ('bottled water', 'rolls/buns', 'whole milk'): 86,
#   ('newspapers', 'rolls/buns', 'whole milk'): 75,
#   ('bottled beer', 'rolls/buns', 'whole milk'): 53,
#   ('hamburger meat', 'other vegetables', 'whole milk'): 62,
#   ('domestic eggs', 'other vegetables', 'whole milk'): 121,
#   ('domestic eggs', 'other vegetables', 'soda'): 50,
#   ('citrus fruit', 'pip fruit', 'tropical fruit'): 55,
#   ('citrus fruit', 'pip fruit', 'whole milk'): 51,
#   ('domestic eggs', 'pip fruit', 'whole milk'): 53,
#   ('fruit/vegetable juice', 'tropical fruit', 'whole milk'): 59,
#   ('sausage', 'tropical fruit', 'whole milk'): 71,
#   ('frankfurter', 'tropical fruit', 'whole milk'): 51,
#   ('pip fruit', 'sausage', 'whole milk'): 55,
#   ('frankfurter', 'rolls/buns', 'whole milk'): 59,
#   ('other vegetables', 'pip fruit', 'whole milk'): 133,
#   ('other vegetables', 'pip fruit', 'rolls/buns'): 50,
#   ('frankfurter', 'other vegetables', 'whole milk'): 75,
#   ('other vegetables', 'shopping bags', 'whole milk'): 75,
#   ('chocolate', 'other vegetables', 'whole milk'): 54,
#   ('curd', 'other vegetables', 'yogurt'): 60,
#   ('other vegetables', 'whole milk', 'yogurt'): 219,
#   ('bottled beer', 'other vegetables', 'whole milk'): 75,
#   ('other vegetables', 'root vegetables', 'yogurt'): 127,
#   ('fruit/vegetable juice', 'other vegetables', 'whole milk'): 103,
#   ('fruit/vegetable juice', 'other vegetables', 'root vegetables'): 65,
#   ('fruit/vegetable juice', 'other vegetables', 'yogurt'): 81,
#   ('frozen vegetables', 'whole milk', 'yogurt'): 60,
#   ('frozen vegetables', 'other vegetables', 'root vegetables'): 60,
#   ('frozen vegetables', 'other vegetables', 'yogurt'): 52,
#   ('bottled water', 'soda', 'whole milk'): 74,
#   ('other vegetables', 'tropical fruit', 'whole milk'): 168,
#   ('butter', 'rolls/buns', 'whole milk'): 65,
#   ('other vegetables', 'white bread', 'whole milk'): 58,
#   ('brown bread', 'other vegetables', 'whole milk'): 92,
#   ('tropical fruit', 'whipped/sour cream', 'yogurt'): 61,
#   ('cream cheese', 'whole milk', 'yogurt'): 65,
#   ('cream cheese', 'other vegetables', 'yogurt'): 52,
#   ('pip fruit', 'tropical fruit', 'yogurt'): 63,
#   ('pip fruit', 'whole milk', 'yogurt'): 94,
#   ('pip fruit', 'root vegetables', 'yogurt'): 52,
#   ('butter', 'other vegetables', 'yogurt'): 63,
#   ('butter', 'other vegetables', 'whole milk'): 113,
#   ('butter', 'root vegetables', 'whole milk'): 81,
#   ('butter', 'whipped/sour cream', 'whole milk'): 66,
#   ('butter', 'domestic eggs', 'whole milk'): 59,
#   ('other vegetables', 'tropical fruit', 'whipped/sour cream'): 77,
#   ('other vegetables', 'pip fruit', 'tropical fruit'): 93,
#   ('other vegetables', 'tropical fruit', 'yogurt'): 121,
#   ('tropical fruit', 'whipped/sour cream', 'whole milk'): 78,
#   ('curd', 'other vegetables', 'whole milk'): 97,
#   ('curd', 'root vegetables', 'whole milk'): 61,
#   ('curd', 'whipped/sour cream', 'whole milk'): 58,
#   ('other vegetables', 'pip fruit', 'root vegetables'): 80,
#   ('root vegetables', 'whipped/sour cream', 'whole milk'): 93,
#   ('whipped/sour cream', 'whole milk', 'yogurt'): 107,
#   ('other vegetables', 'pip fruit', 'whipped/sour cream'): 55,
#   ('other vegetables', 'whipped/sour cream', 'yogurt'): 100,
#   ('root vegetables', 'whipped/sour cream', 'yogurt'): 63,
#   ('domestic eggs', 'other vegetables', 'yogurt'): 57,
#   ('domestic eggs', 'whipped/sour cream', 'whole milk'): 56,
#   ('domestic eggs', 'other vegetables', 'root vegetables'): 72,
#   ('domestic eggs', 'other vegetables', 'whipped/sour cream'): 50,
#   ('pip fruit', 'root vegetables', 'tropical fruit'): 52,
#   ('pip fruit', 'root vegetables', 'whole milk'): 88,
#   ('pip fruit', 'whipped/sour cream', 'whole milk'): 59,
#   ('frankfurter', 'root vegetables', 'whole milk'): 50,
#   ('frankfurter', 'whole milk', 'yogurt'): 61,
#   ('cream cheese', 'other vegetables', 'whole milk'): 66,
#   ('other vegetables', 'pip fruit', 'yogurt'): 80,
#   ('beef', 'root vegetables', 'whole milk'): 79,
#   ('other vegetables', 'pork', 'root vegetables'): 69,
#   ('pork', 'root vegetables', 'whole milk'): 67,
#   ('sausage', 'soda', 'yogurt'): 55,
#   ('other vegetables', 'sausage', 'soda'): 71,
#   ('other vegetables', 'shopping bags', 'soda'): 53,
#   ('other vegetables', 'soda', 'yogurt'): 82,
#   ('other vegetables', 'sausage', 'shopping bags'): 53,
#   ('other vegetables', 'sausage', 'yogurt'): 80,
#   ('other vegetables', 'shopping bags', 'yogurt'): 53,
#   ('beef', 'rolls/buns', 'whole milk'): 67,
#   ('other vegetables', 'sausage', 'whole milk'): 100,
#   ('citrus fruit', 'whipped/sour cream', 'whole milk'): 62,
#   ('citrus fruit', 'other vegetables', 'whole milk'): 128,
#   ('citrus fruit', 'rolls/buns', 'whole milk'): 71,
#   ('beef', 'other vegetables', 'rolls/buns'): 57,
#   ('beef', 'other vegetables', 'whole milk'): 91,
#   ('sausage', 'whipped/sour cream', 'whole milk'): 50,
#   ('citrus fruit', 'other vegetables', 'whipped/sour cream'): 56,
#   ('citrus fruit', 'other vegetables', 'rolls/buns'): 59,
#   ('other vegetables', 'root vegetables', 'shopping bags'): 65,
#   ('bottled water', 'citrus fruit', 'other vegetables'): 50,
#   ('citrus fruit', 'rolls/buns', 'yogurt'): 57,
#   ('curd', 'rolls/buns', 'whole milk'): 58,
#   ('napkins', 'rolls/buns', 'whole milk'): 52,
#   ('rolls/buns', 'whole milk', 'yogurt'): 153,
#   ('bottled water', 'other vegetables', 'whole milk'): 106,
#   ('bottled water', 'other vegetables', 'soda'): 56,
#   ('napkins', 'other vegetables', 'whole milk'): 67,
#   ('bottled beer', 'bottled water', 'whole milk'): 60,
#   ('bottled water', 'root vegetables', 'whole milk'): 72,
#   ('other vegetables', 'rolls/buns', 'soda'): 97,
#   ('other vegetables', 'pork', 'rolls/buns'): 55,
#   ('other vegetables', 'rolls/buns', 'shopping bags'): 52,
#   ('other vegetables', 'rolls/buns', 'yogurt'): 113,
#   ('other vegetables', 'soda', 'tropical fruit'): 71,
#   ('other vegetables', 'sausage', 'tropical fruit'): 59,
#   ('bottled water', 'rolls/buns', 'tropical fruit'): 53,
#   ('bottled water', 'soda', 'tropical fruit'): 51,
#   ('bottled water', 'other vegetables', 'yogurt'): 80,
#   ('bottled water', 'other vegetables', 'sausage'): 50,
#   ('citrus fruit', 'other vegetables', 'yogurt'): 75,
#   ('rolls/buns', 'soda', 'tropical fruit'): 53,
#   ('newspapers', 'tropical fruit', 'whole milk'): 50,
#   ('rolls/buns', 'tropical fruit', 'yogurt'): 86,
#   ('chocolate', 'soda', 'whole milk'): 50,
#   ('newspapers', 'whole milk', 'yogurt'): 65,
#   ('newspapers', 'other vegetables', 'yogurt'): 55,
#   ('newspapers', 'other vegetables', 'rolls/buns'): 54,
#   ('newspapers', 'other vegetables', 'whole milk'): 82,
#   ('other vegetables', 'pastry', 'root vegetables'): 58,
#   ('hygiene articles', 'other vegetables', 'whole milk'): 51,
#   ('onions', 'other vegetables', 'whole milk'): 65,
#   ('citrus fruit', 'root vegetables', 'whole milk'): 90,
#   ('margarine', 'other vegetables', 'whole milk'): 91,
#   ('margarine', 'other vegetables', 'root vegetables'): 58,
#   ('citrus fruit', 'other vegetables', 'pip fruit'): 58,
#   ('other vegetables', 'pastry', 'whole milk'): 104,
#   ('other vegetables', 'pastry', 'rolls/buns'): 60,
#   ('bottled water', 'fruit/vegetable juice', 'whole milk'): 57,
#   ('pastry', 'rolls/buns', 'yogurt'): 57,
#   ('margarine', 'other vegetables', 'rolls/buns'): 51,
#   ('margarine', 'other vegetables', 'yogurt'): 56,
#   ('margarine', 'whole milk', 'yogurt'): 69,
#   ('other vegetables', 'pastry', 'yogurt'): 65,
#   ('chicken', 'other vegetables', 'whole milk'): 83,
#   ('chicken', 'rolls/buns', 'whole milk'): 52,
#   ('chicken', 'root vegetables', 'whole milk'): 59,
#   ('brown bread', 'rolls/buns', 'whole milk'): 52,
#   ('oil', 'other vegetables', 'whole milk'): 50,
#   ('beef', 'other vegetables', 'yogurt'): 51,
#   ('root vegetables', 'sausage', 'whole milk'): 76,
#   ('brown bread', 'other vegetables', 'yogurt'): 51,
#   ('rolls/buns', 'shopping bags', 'whole milk'): 52,
#   ('other vegetables', 'pastry', 'soda'): 54,
#   ('coffee', 'other vegetables', 'whole milk'): 63,
#   ('other vegetables', 'root vegetables', 'soda'): 81,
#   ('onions', 'other vegetables', 'root vegetables'): 56,
#   ('beef', 'other vegetables', 'root vegetables'): 78,
#   ('fruit/vegetable juice', 'soda', 'whole milk'): 60,
#   ('bottled water', 'fruit/vegetable juice', 'soda'): 51,
#   ('pastry', 'pip fruit', 'whole milk'): 50,
#   ('beef', 'whole milk', 'yogurt'): 60,
#   ('newspapers', 'root vegetables', 'whole milk'): 57,
#   ('fruit/vegetable juice', 'soda', 'yogurt'): 50,
#   ('domestic eggs', 'other vegetables', 'rolls/buns'): 58,
#   ('shopping bags', 'soda', 'whole milk'): 67,
#   ('root vegetables', 'shopping bags', 'whole milk'): 52,
#   ('other vegetables', 'pastry', 'tropical fruit'): 50,
#   ('newspapers', 'other vegetables', 'root vegetables'): 59},
#  {('root vegetables', 'tropical fruit', 'whole milk', 'yogurt'): 56,
#   ('other vegetables', 'root vegetables', 'whole milk', 'yogurt'): 77,
#   ('fruit/vegetable juice', 'other vegetables', 'whole milk', 'yogurt'): 50,
#   ('other vegetables', 'root vegetables', 'tropical fruit', 'whole milk'): 69,
#   ('other vegetables',
#    'root vegetables',
#    'whipped/sour cream',
#    'whole milk'): 51,
#   ('other vegetables', 'whipped/sour cream', 'whole milk', 'yogurt'): 55,
#   ('other vegetables', 'pip fruit', 'root vegetables', 'whole milk'): 54,
#   ('other vegetables', 'pip fruit', 'whole milk', 'yogurt'): 50,
#   ('other vegetables', 'tropical fruit', 'whole milk', 'yogurt'): 75,
#   ('other vegetables', 'rolls/buns', 'root vegetables', 'whole milk'): 61,
#   ('other vegetables', 'rolls/buns', 'whole milk', 'yogurt'): 59,
#   ('citrus fruit', 'other vegetables', 'root vegetables', 'whole milk'): 57}]

# %%
optimized_generate_frequent_itemsets(data_path, min_sup=0.005)
# Out:
# gen_by_comb executed in 0.0008184609996533254 seconds
# gen_by_comb executed in 0.005448461999549181 seconds
# gen_by_comb executed in 5.5606999922019895e-05 seconds
# optimized_generate_frequent_itemsets executed in 266.63636157900055 seconds
# [{('citrus fruit',): 814,
#   ('margarine',): 576,
#   ('semi-finished bread',): 174,
#   ('coffee',): 571,
#   ('tropical fruit',): 1032,
#   ('yogurt',): 1372,
#   ('whole milk',): 2513,
#   ('cream cheese',): 390,
#   ('pip fruit',): 744,
#   ('condensed milk',): 101,
#   ('long life bakery product',): 368,
#   ('other vegetables',): 1903,
#   ('butter',): 545,
#   ('rice',): 75,
#   ('rolls/buns',): 1809,
#   ('UHT-milk',): 329,
#   ('bottled beer',): 792,
#   ('liquor (appetizer)',): 78,
#   ('potted plants',): 170,
#   ('cereals',): 56,
#   ('bottled water',): 1087,
#   ('chocolate',): 488,
#   ('white bread',): 414,
#   ('curd',): 524,
#   ('dishes',): 173,
#   ('flour',): 171,
#   ('beef',): 516,
#   ('frankfurter',): 580,
#   ('soda',): 1715,
#   ('chicken',): 422,
#   ('fruit/vegetable juice',): 711,
#   ('newspapers',): 785,
#   ('sugar',): 333,
#   ('packaged fruit/vegetables',): 128,
#   ('specialty bar',): 269,
#   ('butter milk',): 275,
#   ('pastry',): 875,
#   ('detergent',): 189,
#   ('processed cheese',): 163,
#   ('candy',): 294,
#   ('frozen dessert',): 106,
#   ('root vegetables',): 1072,
#   ('salty snack',): 372,
#   ('sweet spreads',): 89,
#   ('waffles',): 378,
#   ('canned beer',): 764,
#   ('sausage',): 924,
#   ('brown bread',): 638,
#   ('shopping bags',): 969,
#   ('beverages',): 256,
#   ('hamburger meat',): 327,
#   ('hygiene articles',): 324,
#   ('napkins',): 515,
#   ('spices',): 51,
#   ('berries',): 327,
#   ('pork',): 567,
#   ('whipped/sour cream',): 705,
#   ('grapes',): 220,
#   ('dessert',): 365,
#   ('zwieback',): 68,
#   ('domestic eggs',): 624,
#   ('spread cheese',): 110,
#   ('misc. beverages',): 279,
#   ('hard cheese',): 241,
#   ('cat food',): 229,
#   ('ham',): 256,
#   ('baking powder',): 174,
#   ('turkey',): 80,
#   ('pickled vegetables',): 176,
#   ('chewing gum',): 207,
#   ('chocolate marshmallow',): 89,
#   ('oil',): 276,
#   ('ice cream',): 246,
#   ('canned fish',): 148,
#   ('frozen vegetables',): 473,
#   ('seasonal products',): 140,
#   ('curd cheese',): 50,
#   ('red/blush wine',): 189,
#   ('frozen potato products',): 83,
#   ('candles',): 88,
#   ('flower (seeds)',): 102,
#   ('specialty chocolate',): 299,
#   ('sparkling wine',): 55,
#   ('salt',): 106,
#   ('frozen meals',): 279,
#   ('canned vegetables',): 106,
#   ('onions',): 305,
#   ('herbs',): 160,
#   ('white wine',): 187,
#   ('photo/film',): 91,
#   ('sliced cheese',): 241,
#   ('pasta',): 148,
#   ('softener',): 54,
#   ('cling film/bags',): 112,
#   ('Instant food products',): 79,
#   ('soft cheese',): 168,
#   ('dental care',): 57,
#   ('popcorn',): 71,
#   ('cake bar',): 130,
#   ('specialty cheese',): 84,
#   ('finished products',): 64,
#   ('dog food',): 84,
#   ('frozen fish',): 115,
#   ('cleaner',): 50,
#   ('female sanitary products',): 60,
#   ('dish cleaner',): 103,
#   ('meat',): 254,
#   ('mustard',): 118,
#   ('house keeping products',): 82,
#   ('liquor',): 109,
#   ('pet care',): 93,
#   ('soups',): 67,
#   ('sauces',): 54,
#   ('vinegar',): 64,
#   ('instant coffee',): 73,
#   ('roll products',): 101,
#   ('mayonnaise',): 90,
#   ('liver loaf',): 50,
#   ('kitchen towels',): 59,
#   ('jam',): 53},
#  {('citrus fruit', 'margarine'): 78,
#   ('coffee', 'tropical fruit'): 70,
#   ('cream cheese', 'yogurt'): 122,
#   ('cream cheese', 'pip fruit'): 60,
#   ('long life bakery product', 'other vegetables'): 105,
#   ('whole milk', 'yogurt'): 551,
#   ('butter', 'yogurt'): 144,
#   ('bottled beer', 'other vegetables'): 159,
#   ('UHT-milk', 'other vegetables'): 80,
#   ('bottled water', 'tropical fruit'): 182,
#   ('bottled water', 'chocolate'): 57,
#   ('bottled water', 'other vegetables'): 244,
#   ('chocolate', 'other vegetables'): 125,
#   ('bottled water', 'citrus fruit'): 133,
#   ('bottled water', 'butter'): 88,
#   ('bottled water', 'yogurt'): 226,
#   ('bottled water', 'curd'): 60,
#   ('citrus fruit', 'yogurt'): 213,
#   ('citrus fruit', 'curd'): 70,
#   ('citrus fruit', 'tropical fruit'): 196,
#   ('butter', 'curd'): 67,
#   ('butter', 'tropical fruit'): 98,
#   ('curd', 'tropical fruit'): 101,
#   ('frankfurter', 'rolls/buns'): 189,
#   ('frankfurter', 'soda'): 111,
#   ('rolls/buns', 'soda'): 377,
#   ('chicken', 'tropical fruit'): 63,
#   ('fruit/vegetable juice', 'newspapers'): 81,
#   ('cream cheese', 'tropical fruit'): 71,
#   ('newspapers', 'tropical fruit'): 116,
#   ('salty snack', 'tropical fruit'): 55,
#   ('rolls/buns', 'root vegetables'): 239,
#   ('rolls/buns', 'tropical fruit'): 242,
#   ('root vegetables', 'tropical fruit'): 207,
#   ('candy', 'tropical fruit'): 53,
#   ('candy', 'other vegetables'): 68,
#   ('flour', 'other vegetables'): 62,
#   ('bottled water', 'canned beer'): 79,
#   ('rolls/buns', 'sausage'): 301,
#   ('sausage', 'soda'): 239,
#   ('fruit/vegetable juice', 'shopping bags'): 105,
#   ('fruit/vegetable juice', 'soda'): 181,
#   ('shopping bags', 'soda'): 242,
#   ('brown bread', 'newspapers'): 75,
#   ('brown bread', 'soda'): 124,
#   ('newspapers', 'soda'): 144,
#   ('canned beer', 'soda'): 136,
#   ('beverages', 'yogurt'): 54,
#   ('hygiene articles', 'rolls/buns'): 58,
#   ('hygiene articles', 'napkins'): 60,
#   ('hygiene articles', 'other vegetables'): 94,
#   ('bottled water', 'rolls/buns'): 238,
#   ('bottled water', 'napkins'): 85,
#   ('hamburger meat', 'other vegetables'): 136,
#   ('napkins', 'other vegetables'): 142,
#   ('beverages', 'other vegetables'): 51,
#   ('berries', 'soda'): 72,
#   ('berries', 'other vegetables'): 101,
#   ('pork', 'soda'): 117,
#   ('pastry', 'soda'): 207,
#   ('dessert', 'whole milk'): 135,
#   ('dessert', 'root vegetables'): 57,
#   ('dessert', 'other vegetables'): 114,
#   ('citrus fruit', 'newspapers'): 82,
#   ('rolls/buns', 'specialty bar'): 55,
#   ('domestic eggs', 'pastry'): 89,
#   ('domestic eggs', 'yogurt'): 141,
#   ('domestic eggs', 'root vegetables'): 141,
#   ('domestic eggs', 'soda'): 122,
#   ('domestic eggs', 'tropical fruit'): 112,
#   ('waffles', 'yogurt'): 74,
#   ('sugar', 'yogurt'): 68,
#   ('brown bread', 'pastry'): 95,
#   ('brown bread', 'yogurt'): 143,
#   ('brown bread', 'root vegetables'): 100,
#   ('brown bread', 'tropical fruit'): 105,
#   ('pastry', 'yogurt'): 174,
#   ('pastry', 'root vegetables'): 108,
#   ('pastry', 'tropical fruit'): 130,
#   ('root vegetables', 'soda'): 183,
#   ('candy', 'soda'): 85,
#   ('soda', 'tropical fruit'): 205,
#   ('berries', 'yogurt'): 104,
#   ('bottled water', 'cream cheese'): 58,
#   ('bottled water', 'newspapers'): 111,
#   ('bottled water', 'soda'): 285,
#   ('cream cheese', 'rolls/buns'): 98,
#   ('cream cheese', 'soda'): 67,
#   ('rolls/buns', 'yogurt'): 338,
#   ('butter milk', 'yogurt'): 84,
#   ('newspapers', 'yogurt'): 151,
#   ('bottled water', 'pastry'): 88,
#   ('bottled water', 'whipped/sour cream'): 86,
#   ('bottled water', 'root vegetables'): 154,
#   ('long life bakery product', 'root vegetables'): 52,
#   ('butter', 'root vegetables'): 127,
#   ('butter', 'other vegetables'): 197,
#   ('curd', 'other vegetables'): 169,
#   ('hard cheese', 'other vegetables'): 93,
#   ('newspapers', 'sausage'): 79,
#   ('grapes', 'other vegetables'): 89,
#   ('ham', 'other vegetables'): 90,
#   ('fruit/vegetable juice', 'tropical fruit'): 135,
#   ('fruit/vegetable juice', 'other vegetables'): 207,
#   ('fruit/vegetable juice', 'margarine'): 61,
#   ('domestic eggs', 'other vegetables'): 219,
#   ('domestic eggs', 'margarine'): 82,
#   ('brown bread', 'other vegetables'): 184,
#   ('brown bread', 'margarine'): 64,
#   ('curd', 'margarine'): 62,
#   ('baking powder', 'other vegetables'): 72,
#   ('processed cheese', 'soda'): 52,
#   ('oil', 'rolls/buns'): 50,
#   ('salty snack', 'whole milk'): 110,
#   ('canned fish', 'other vegetables'): 50,
#   ('detergent', 'other vegetables'): 63,
#   ('frozen vegetables', 'other vegetables'): 175,
#   ('pastry', 'sausage'): 123,
#   ('frankfurter', 'tropical fruit'): 93,
#   ('berries', 'tropical fruit'): 66,
#   ('pip fruit', 'tropical fruit'): 201,
#   ('butter', 'margarine'): 66,
#   ('domestic eggs', 'newspapers'): 68,
#   ('citrus fruit', 'pastry'): 96,
#   ('bottled beer', 'soda'): 167,
#   ('fruit/vegetable juice', 'whole milk'): 262,
#   ('fruit/vegetable juice', 'rolls/buns'): 143,
#   ('fruit/vegetable juice', 'root vegetables'): 118,
#   ('oil', 'root vegetables'): 69,
#   ('domestic eggs', 'rolls/buns'): 154,
#   ('domestic eggs', 'frozen vegetables'): 51,
#   ('frozen vegetables', 'margarine'): 50,
#   ('onions', 'root vegetables'): 93,
#   ('onions', 'rolls/buns'): 67,
#   ('onions', 'yogurt'): 71,
#   ('onions', 'whipped/sour cream'): 50,
#   ('berries', 'citrus fruit'): 53,
#   ('citrus fruit', 'pork'): 64,
#   ('citrus fruit', 'coffee'): 63,
#   ('fruit/vegetable juice', 'sausage'): 99,
#   ('shopping bags', 'waffles'): 54,
#   ('brown bread', 'sausage'): 105,
#   ('oil', 'other vegetables'): 98,
#   ('chicken', 'citrus fruit'): 68,
#   ('chicken', 'root vegetables'): 107,
#   ('chicken', 'other vegetables'): 176,
#   ('citrus fruit', 'root vegetables'): 174,
#   ('citrus fruit', 'other vegetables'): 284,
#   ('hamburger meat', 'root vegetables'): 61,
#   ('misc. beverages', 'soda'): 72,
#   ('pastry', 'pork'): 62,
#   ('bottled water', 'frankfurter'): 72,
#   ('fruit/vegetable juice', 'yogurt'): 184,
#   ('fruit/vegetable juice', 'napkins'): 68,
#   ('shopping bags', 'yogurt'): 150,
#   ('bottled beer', 'yogurt'): 91,
#   ('bottled beer', 'sausage'): 77,
#   ('bottled beer', 'napkins'): 51,
#   ('berries', 'root vegetables'): 65,
#   ('brown bread', 'citrus fruit'): 82,
#   ('beef', 'root vegetables'): 171,
#   ('dishes', 'other vegetables'): 59,
#   ('frankfurter', 'sausage'): 99,
#   ('frankfurter', 'root vegetables'): 100,
#   ('frankfurter', 'other vegetables'): 162,
#   ('bottled beer', 'root vegetables'): 95,
#   ('dessert', 'rolls/buns'): 67,
#   ('bottled water', 'frozen vegetables'): 61,
#   ('bottled water', 'margarine'): 101,
#   ('hamburger meat', 'soda'): 57,
#   ('long life bakery product', 'pastry'): 58,
#   ('coffee', 'other vegetables'): 132,
#   ('long life bakery product', 'sausage'): 53,
#   ('fruit/vegetable juice', 'pip fruit'): 94,
#   ('hygiene articles', 'whole milk'): 126,
#   ('hygiene articles', 'tropical fruit'): 66,
#   ('cream cheese', 'domestic eggs'): 50,
#   ('cream cheese', 'sausage'): 55,
#   ('frankfurter', 'pip fruit'): 71,
#   ('domestic eggs', 'sausage'): 94,
#   ('domestic eggs', 'pip fruit'): 85,
#   ('citrus fruit', 'sausage'): 111,
#   ('citrus fruit', 'pip fruit'): 136,
#   ('sausage', 'tropical fruit'): 137,
#   ('frankfurter', 'margarine'): 63,
#   ('canned beer', 'other vegetables'): 89,
#   ('misc. beverages', 'other vegetables'): 55,
#   ('frankfurter', 'frozen vegetables'): 50,
#   ('rolls/buns', 'soft cheese'): 53,
#   ('dessert', 'sausage'): 58,
#   ('dessert', 'yogurt'): 97,
#   ('chewing gum', 'soda'): 53,
#   ('fruit/vegetable juice', 'white bread'): 73,
#   ('bottled beer', 'brown bread'): 51,
#   ('bottled beer', 'tropical fruit'): 81,
#   ('ham', 'tropical fruit'): 53,
#   ('salty snack', 'shopping bags'): 59,
#   ('salty snack', 'soda'): 92,
#   ('dessert', 'shopping bags'): 61,
#   ('dessert', 'soda'): 97,
#   ('curd', 'soda'): 80,
#   ('ice cream', 'other vegetables'): 50,
#   ('fruit/vegetable juice', 'whipped/sour cream'): 89,
#   ('white bread', 'yogurt'): 89,
#   ('sliced cheese', 'yogurt'): 79,
#   ('sliced cheese', 'tropical fruit'): 52,
#   ('whipped/sour cream', 'yogurt'): 204,
#   ('cream cheese', 'root vegetables'): 74,
#   ('cream cheese', 'curd'): 50,
#   ('cream cheese', 'other vegetables'): 135,
#   ('frankfurter', 'yogurt'): 110,
#   ('bottled beer', 'butter'): 57,
#   ('bottled beer', 'pip fruit'): 58,
#   ('ham', 'yogurt'): 66,
#   ('butter', 'pip fruit'): 72,
#   ('pip fruit', 'root vegetables'): 153,
#   ('frozen meals', 'tropical fruit'): 54,
#   ('frozen meals', 'other vegetables'): 74,
#   ('shopping bags', 'tropical fruit'): 133,
#   ('beef', 'pork'): 75,
#   ('pip fruit', 'pork'): 60,
#   ('hygiene articles', 'yogurt'): 72,
#   ('hygiene articles', 'soda'): 69,
#   ('butter', 'soda'): 87,
#   ('UHT-milk', 'soda'): 75,
#   ('beef', 'margarine'): 61,
#   ('beverages', 'rolls/buns'): 53,
#   ('butter milk', 'other vegetables'): 102,
#   ('beef', 'other vegetables'): 194,
#   ('sliced cheese', 'soda'): 50,
#   ('onions', 'tropical fruit'): 56,
#   ('bottled water', 'brown bread'): 81,
#   ('meat', 'rolls/buns'): 68,
#   ('meat', 'other vegetables'): 98,
#   ('salty snack', 'sausage'): 52,
#   ('butter', 'sausage'): 85,
#   ('herbs', 'root vegetables'): 69,
#   ('herbs', 'other vegetables'): 76,
#   ('citrus fruit', 'napkins'): 75,
#   ('bottled water', 'misc. beverages'): 52,
#   ('napkins', 'soda'): 118,
#   ('shopping bags', 'whipped/sour cream'): 78,
#   ('bottled water', 'sausage'): 118,
#   ('bottled water', 'pip fruit'): 104,
#   ('citrus fruit', 'soda'): 126,
#   ('newspapers', 'other vegetables'): 190,
#   ('onions', 'whole milk'): 119,
#   ('onions', 'soda'): 52,
#   ('onions', 'other vegetables'): 140,
#   ('domestic eggs', 'napkins'): 59,
#   ('pip fruit', 'soda'): 131,
#   ('napkins', 'tropical fruit'): 99,
#   ('meat', 'root vegetables'): 50,
#   ('meat', 'soda'): 54,
#   ('hygiene articles', 'root vegetables'): 53,
#   ('butter milk', 'root vegetables'): 50,
#   ('butter milk', 'tropical fruit'): 54,
#   ('brown bread', 'pip fruit'): 75,
#   ('fruit/vegetable juice', 'pastry'): 84,
#   ('chicken', 'yogurt'): 82,
#   ('chicken', 'soda'): 82,
#   ('pastry', 'pip fruit'): 105,
#   ('bottled water', 'domestic eggs'): 90,
#   ('potted plants', 'whole milk'): 68,
#   ('bottled water', 'chicken'): 52,
#   ('chicken', 'newspapers'): 51,
#   ('oil', 'yogurt'): 52,
#   ('chicken', 'sausage'): 52,
#   ('brown bread', 'pork'): 55,
#   ('meat', 'sausage'): 52,
#   ('frankfurter', 'pork'): 58,
#   ('brown bread', 'butter'): 57,
#   ('butter', 'pork'): 54,
#   ('frankfurter', 'pastry'): 82,
#   ('cat food', 'other vegetables'): 64,
#   ('butter', 'frozen vegetables'): 57,
#   ('fruit/vegetable juice', 'long life bakery product'): 61,
#   ('long life bakery product', 'yogurt'): 86,
#   ('bottled beer', 'margarine'): 60,
#   ('pork', 'tropical fruit'): 84,
#   ('citrus fruit', 'frozen vegetables'): 65,
#   ('beef', 'soda'): 80,
#   ('beef', 'tropical fruit'): 75,
#   ('butter milk', 'pip fruit'): 50,
#   ('frozen meals', 'soda'): 61,
#   ('bottled water', 'coffee'): 72,
#   ('newspapers', 'pork'): 65,
#   ('salty snack', 'yogurt'): 61,
#   ('frozen vegetables', 'tropical fruit'): 86,
#   ('hygiene articles', 'shopping bags'): 51,
#   ('domestic eggs', 'pork'): 55,
#   ('bottled water', 'pork'): 73,
#   ('meat', 'yogurt'): 52,
#   ('newspapers', 'root vegetables'): 113,
#   ('long life bakery product', 'soda'): 75,
#   ('newspapers', 'pip fruit'): 66,
#   ('grapes', 'tropical fruit'): 60,
#   ('long life bakery product', 'tropical fruit'): 62,
#   ('bottled beer', 'citrus fruit'): 60,
#   ('bottled beer', 'pork'): 51,
#   ('chicken', 'pork'): 57,
#   ('chicken', 'frozen vegetables'): 66,
#   ('ice cream', 'soda'): 60,
#   ('salty snack', 'whipped/sour cream'): 51,
#   ('butter', 'chocolate'): 61,
#   ('dessert', 'fruit/vegetable juice'): 59,
#   ('dessert', 'pastry'): 53,
#   ('dessert', 'tropical fruit'): 62},
#  {('rolls/buns', 'root vegetables', 'tropical fruit'): 58,
#   ('rolls/buns', 'sausage', 'soda'): 95,
#   ('bottled water', 'rolls/buns', 'yogurt'): 70,
#   ('bottled water', 'rolls/buns', 'soda'): 67,
#   ('citrus fruit', 'root vegetables', 'tropical fruit'): 56,
#   ('fruit/vegetable juice', 'whole milk', 'yogurt'): 93,
#   ('citrus fruit', 'pip fruit', 'tropical fruit'): 55,
#   ('pip fruit', 'root vegetables', 'tropical fruit'): 52,
#   ('bottled water', 'citrus fruit', 'other vegetables'): 50,
#   ('bottled water', 'rolls/buns', 'tropical fruit'): 53,
#   ('bottled water', 'soda', 'tropical fruit'): 51,
#   ('rolls/buns', 'soda', 'tropical fruit'): 53}]

# %%
from itertools import  combinations

a = [1, 2,]
b = [6, 7, 8]

tp = []
for combination in combinations(b, 2):
    tp.append(tuple(a) + tuple(sorted(combination)))

# %%
d: dict = {}

if not d:
    print(True)
# Out:
# True
