# %%
import matplotlib.pyplot as plt
import numpy as np


x_axis = [1, 2, 3, 4, 5, 6]
nursery_cba_accuracy = [89.9, 90.1, 92.7, 94.4, 95.91, 98.53]
nursery_cba_time = [2, 2.5, 12, 25, 36, 68]

nursery_ga_time = [15, 16, 16.3, 17, 17.2, 17.5]
nursery_ga_accuracy = [87.92, 90.12, 93.17, 93.4, 93.7, 94.48]


fig = plt.figure()

ax = fig.add_subplot(1, 1, 1)
ax.set_title("Nursery Dataset")
ax.set_ylabel("Accuracy")
ax.set_xlabel("Support")
ax.set_ylim([50, 100])

ax2 = ax.twinx()
ax2.set_ylabel("Time (second)")

x_labels = ["5%", "3%", "1%", "0.5%", "0.3%", "0.1%"]

accuracy_labels = [f'{10 * i}%' for i in range(11)]

ax.set_yticks([10 * i for i in range(0, 11)])

x = np.arange(len(x_labels))
width = 0.35

ax.set_xticks(x, x_labels)
ax.set_yticklabels(accuracy_labels)

# ax.bar(x - width / 2, nursery_cba_accuracy, fill=False, width=width, hatch="o")
# ax.bar(x + width / 2, nursery_ga_accuracy, fill=False, width=width, hatch='x')


ax.bar(x - width / 2, nursery_cba_accuracy, width=width)
ax.bar(x + width / 2, nursery_ga_accuracy, width=width)

ax2.plot(x, nursery_cba_time, color="black", marker="o")
ax2.plot(x, nursery_ga_time, color="black", marker="x")


# handles1, labels1 = ax.get_legend_handles_labels()
# handles2, label2 = ax2.get_legend_handles_labels()


# ax.legend(
#     (*handles1, *handles2),
#     (*len(labels1) * [""], *label2),
#     loc="upper right",
#     ncol=2,
#     handlelength=3,
#     edgecolor="black",
#     borderpad=0.7,
#     handletextpad=1.5,
#     columnspacing=0,
# )

fig.tight_layout()
plt.show()

# %%
x_labels = ["5%", "3%", "1%", "0.5%", "0.3%"]
x = np.arange(len(x_labels))
width = 0.35


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.set_ylim([0, 100])
ax.set_title("Adult Dataset (popsize 100)")
ax.set_yticks([10 * i for i in range(0, 11)])

adult_cba_accuracy = [81.5, 83.31, 83.8, 84.5, 84.61]
adult_cba_time = [83 + 67, 175 + 126, 564 + 417, 1240 + 718, 2174 + 1167]

adult_ga_accuracy = [81.58, 83.17, 83.69, 84.3, 84.58]
adult_ga_time = [17.4 + 18.4, 16.5 + 26.7, 15.26 + 33, 18.47 + 38.75, 19.1 + 38.8]

ax2 = ax.twinx()
ax.set_ylabel("Accuracy")
ax.set_xlabel('Support')
ax2.set_ylabel("Time (second)")
ax.set_xticks(x, x_labels)
accuracy_labels = [f'{10 * i}%' for i in range(11)]
ax.set_yticklabels(accuracy_labels)

ax.bar(x - width / 2, adult_cba_accuracy, width=width)
ax.bar(x + width / 2, adult_ga_accuracy, width=width)

ax2.plot(x, adult_cba_time, color="black", marker="o")
ax2.plot(x, adult_ga_time, color="black", marker="x")

# %%
x_labels = ["5%", "3%", "1%", "0.5%", "0.3%"]
x = np.arange(len(x_labels))
width = 0.35
ax.set_xticks(x, x_labels)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_ylim([0, 100])
ax.set_title("Adult Dataset (popsize 300)")
ax.set_yticks([10 * i for i in range(0, 11)])

adult_cba_accuracy = [81.5, 83.31, 83.8, 84.5, 84.61]
adult_cba_time = [83 + 67, 175 + 126, 564 + 417, 1240 + 718, 2174 + 1167]

adult_ga_accuracy = [81.58, 83.17, 83.85, 84.42, 84.58]
adult_ga_time = [57.5 + 33.6, 58.41 + 40.13, 56.67 + 62.9, 56 + 65.5, 61 + 77]

ax2 = ax.twinx()

ax.set_ylabel("Accuracy")
ax.set_xlabel('Support')
ax2.set_ylabel("Time (second)")
ax.set_xticks(x, x_labels)
accuracy_labels = [f'{10 * i}%' for i in range(11)]
ax.set_yticklabels(accuracy_labels)

ax.bar(x - width / 2, adult_cba_accuracy, width=width)
ax.bar(x + width / 2, adult_ga_accuracy, width=width)

ax2.plot(x, adult_cba_time, color="black", marker="o")
ax2.plot(x, adult_ga_time, color="black", marker="x")

# %%
x_labels = ["5%", "3%", "1%"]


fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

x = np.arange(len(x_labels))
width = 0.35
ax.set_xticks(x, x_labels)

ax.set_ylim([0, 100])
ax.set_title("Bank Dataset ")
ax.set_yticks([10 * i for i in range(0, 11)])

bank_cba_accuracy = [89.07,89.11,89.45]
bank_cba_time = [318 + 79,1015 + 171,4499 + 774]

bank_ga_accuracy = [89.12,89.16, 89.26]
bank_ga_time = [38.28 + 25.58, 38 + 29, 35.5 + 35.6]

ax2 = ax.twinx()

ax.set_ylabel("Accuracy")
ax.set_xlabel('Support')
ax2.set_ylabel("Time (second)")
ax.set_xticks(x, x_labels)
accuracy_labels = [f'{10 * i}%' for i in range(11)]
ax.set_yticklabels(accuracy_labels)

ax.bar(x - width / 2, bank_cba_accuracy, width=width)
ax.bar(x + width / 2, bank_ga_accuracy, width=width)

ax2.plot(x, bank_cba_time, color="black", marker="o")
ax2.plot(x, bank_ga_time, color="black", marker="x")
